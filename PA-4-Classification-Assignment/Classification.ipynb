# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
train_df.head(10)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
# 5     e         x           y         y       t    a               f
# 6     e         b           s         w       t    a               f
# 7     e         b           y         w       t    l               f
# 8     p         x           y         w       t    p               f
# 9     e         b           s         y       t    a               f
#
#   gill-spacing gill-size gill-color ... stalk-color-above-ring  \
# 0            c         n          k ...                      w
# 1            c         b          k ...                      w
# 2            c         b          n ...                      w
# 3            c         n          n ...                      w
# 4            w         b          k ...                      w
# 5            c         b          n ...                      w
# 6            c         b          g ...                      w
# 7            c         b          n ...                      w
# 8            c         n          p ...                      w
# 9            c         b          g ...                      w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         p
# 1                      w         p          w           o         p
# 2                      w         p          w           o         p
# 3                      w         p          w           o         p
# 4                      w         p          w           o         e
# 5                      w         p          w           o         p
# 6                      w         p          w           o         p
# 7                      w         p          w           o         p
# 8                      w         p          w           o         p
# 9                      w         p          w           o         p
#
#   spore-print-color population habitat Id
# 0                 k          s       u  0
# 1                 n          n       g  1
# 2                 n          n       m  2
# 3                 k          s       u  3
# 4                 n          a       g  4
# 5                 k          n       g  5
# 6                 k          n       m  6
# 7                 n          s       m  7
# 8                 k          v       g  8
# 9                 k          s       m  9
#
# [10 rows x 24 columns]

# %%
test_df.head(10)
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           y         y       t    a               f            c
# 1         b           s         y       t    a               f            c
# 2         b           y         w       t    a               f            c
# 3         f           s         w       t    p               f            c
# 4         f           f         n       f    n               f            c
# 5         x           s         y       t    a               f            w
# 6         b           s         y       t    l               f            c
# 7         s           f         g       f    n               f            c
# 8         x           y         y       t    l               f            c
# 9         x           y         n       t    a               f            c
#
#   gill-size gill-color stalk-shape ... stalk-color-above-ring  \
# 0         b          n           e ...                      w
# 1         b          k           e ...                      w
# 2         b          w           e ...                      w
# 3         n          n           e ...                      w
# 4         n          k           e ...                      w
# 5         n          n           t ...                      w
# 6         b          g           e ...                      w
# 7         n          k           e ...                      w
# 8         b          n           e ...                      w
# 9         b          w           e ...                      w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         p
# 1                      w         p          w           o         p
# 2                      w         p          w           o         p
# 3                      w         p          w           o         p
# 4                      w         p          w           o         p
# 5                      w         p          w           o         p
# 6                      w         p          w           o         p
# 7                      w         p          w           o         p
# 8                      w         p          w           o         p
# 9                      w         p          w           o         p
#
#   spore-print-color population habitat  Id
# 0                 k          s       m  11
# 1                 n          s       m  20
# 2                 n          n       m  23
# 3                 n          v       g  25
# 4                 k          y       u  28
# 5                 n          v       d  29
# 6                 n          n       m  30
# 7                 k          v       u  36
# 8                 k          y       p  41
# 9                 k          s       g  50
#
# [10 rows x 23 columns]

# %%
train_df['class'].value_counts()
# Out:
# e    2956
# p    2701
# Name: class, dtype: int64

# %% [markdown]
# The class distribution of the two classes are relevant balanced, so we don't need to rebalance data

# %%
train_df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# Id                          0
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# Id                          0
# dtype: int64

# %% [markdown]
# We can see that, no field in any rows are null,
#
# we don't need extra processing on missing values

# %% [markdown]
# Next, we convert the one-character class features into number labels

# %%
from sklearn.preprocessing import LabelEncoder

for col in train_df.columns:
    if col == 'Id':
        continue
    labelencoder = LabelEncoder()
    labelencoder.fit(train_df[col])
    
    train_df[col] = labelencoder.transform(train_df[col])
    
    if col in test_df.columns:
        test_df[col] = labelencoder.transform(test_df[col])

# %%
train_df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color ...  stalk-color-above-ring  \
# 0             0          1           4 ...                       7
# 1             0          0           4 ...                       7
# 2             0          0           5 ...                       7
# 3             0          1           5 ...                       7
# 4             1          0           4 ...                       7
#
#    stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 0                       7          0           2            1          4
# 1                       7          0           2            1          4
# 2                       7          0           2            1          4
# 3                       7          0           2            1          4
# 4                       7          0           2            1          0
#
#    spore-print-color  population  habitat  Id
# 0                  2           3        5   0
# 1                  3           2        1   1
# 2                  3           2        3   2
# 3                  2           3        5   3
# 4                  3           0        1   4
#
# [5 rows x 24 columns]

# %%
test_df.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          5            3          9        1     0                1
# 1          0            2          9        1     0                1
# 2          0            3          8        1     0                1
# 3          2            2          8        1     6                1
# 4          2            0          4        0     5                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape ...  \
# 0             0          0           5            0 ...
# 1             0          0           4            0 ...
# 2             0          0          10            0 ...
# 3             0          1           5            0 ...
# 4             0          1           4            0 ...
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       7                       7          0           2
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat  Id
# 0            1          4                  2           3        3  11
# 1            1          4                  3           3        3  20
# 2            1          4                  3           2        3  23
# 3            1          4                  3           4        1  25
# 4            1          4                  2           5        5  28
#
# [5 rows x 23 columns]

# %%
train_df['class'].value_counts()
# Out:
# 0    2956
# 1    2701
# Name: class, dtype: int64

# %% [markdown]
# Now class 0 is e and class 1 is p.

# %%
train_df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  5657.000000  5657.000000  5657.000000  5657.000000  5657.000000
# mean      0.477462     3.365388     1.818101     4.503977     0.417889
# std       0.499536     1.599579     1.232360     2.541250     0.493255
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  5657.000000      5657.000000   5657.000000  5657.000000  5657.000000
# mean      4.131872         0.974898      0.162984     0.305993     4.790525
# std       2.083291         0.156448      0.369384     0.460867     3.516399
# min       0.000000         0.000000      0.000000     0.000000     0.000000
# 25%       2.000000         1.000000      0.000000     0.000000     2.000000
# 50%       5.000000         1.000000      0.000000     0.000000     5.000000
# 75%       5.000000         1.000000      0.000000     1.000000     7.000000
# max       8.000000         1.000000      1.000000     1.000000    11.000000
#
#           ...       stalk-color-above-ring  stalk-color-below-ring  veil-type  \
# count     ...                  5657.000000             5657.000000     5657.0
# mean      ...                     5.789818                5.780803        0.0
# std       ...                     1.925187                1.923492        0.0
# min       ...                     0.000000                0.000000        0.0
# 25%       ...                     6.000000                6.000000        0.0
# 50%       ...                     7.000000                7.000000        0.0
# 75%       ...                     7.000000                7.000000        0.0
# max       ...                     8.000000                8.000000        0.0
#
#         veil-color  ring-number    ring-type  spore-print-color   population  \
# count  5657.000000  5657.000000  5657.000000        5657.000000  5657.000000
# mean      1.966060     1.068588     2.287255           3.581757     3.645925
# std       0.241358     0.269694     1.801903           2.370047     1.249596
# min       0.000000     0.000000     0.000000           0.000000     0.000000
# 25%       2.000000     1.000000     0.000000           2.000000     3.000000
# 50%       2.000000     1.000000     2.000000           3.000000     4.000000
# 75%       2.000000     1.000000     4.000000           7.000000     4.000000
# max       3.000000     2.000000     4.000000           8.000000     5.000000
#
#            habitat           Id
# count  5657.000000  5657.000000
# mean      1.497967  4028.688351
# std       1.724902  2334.652887
# min       0.000000     0.000000
# 25%       0.000000  2007.000000
# 50%       1.000000  4012.000000
# 75%       2.000000  6042.000000
# max       6.000000  8123.000000
#
# [8 rows x 24 columns]

# %%
features = [column for column in train_df.columns]
features.remove('Id')
features.remove('class')
print('Total number of features = %d' % len(features))
# Out:
# Total number of features = 22

# %%
X_all = train_df[features]
y_all = train_df['class']

# %%
X_all.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          5            2          4        1     6                1
# 1          5            2          9        1     0                1
# 2          0            2          8        1     3                1
# 3          5            3          8        1     6                1
# 4          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape   ...     \
# 0             0          1           4            0   ...
# 1             0          0           4            0   ...
# 2             0          0           5            0   ...
# 3             0          1           5            0   ...
# 4             1          0           4            1   ...
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         2                       7                       7
# 1                         2                       7                       7
# 2                         2                       7                       7
# 3                         2                       7                       7
# 4                         2                       7                       7
#
#    veil-type  veil-color  ring-number  ring-type  spore-print-color  \
# 0          0           2            1          4                  2
# 1          0           2            1          4                  3
# 2          0           2            1          4                  3
# 3          0           2            1          4                  2
# 4          0           2            1          0                  3
#
#    population  habitat
# 0           3        5
# 1           2        1
# 2           2        3
# 3           3        5
# 4           0        1
#
# [5 rows x 22 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_all, y_all, test_size=0.2, random_state=4)

# %%
from sklearn.ensemble import RandomForestClassifier

model_RR=RandomForestClassifier()

# %%
model_RR.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred = model_RR.predict(X_val) # This will give you positive class prediction probabilities 
model_RR.score(X_val, y_val)
# Out:
# 1.0

# %%
accuracy = 0
total = len(y_pred)
val_labels = y_val.values

for i in range(total):
    if y_pred[i] == val_labels[i]:
        accuracy = accuracy + 1

print('Accuracy = %d/%d' % (accuracy, total))
# Out:
# Accuracy = 1132/1132

# %% [markdown]
# ### Crazily, 100% validation accuracy is obtained from Random Forest Model. This cannot be improved any more!

# %%
test_data = test_df[features]
test_pred = model_RR.predict(test_data)
test_pred
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
test_df['Id'].head()
# Out:
# 0    11
# 1    20
# 2    23
# 3    25
# 4    28
# Name: Id, dtype: int64

# %%
class_map = {0: 'e', 1: 'p'}
test_pred = [class_map[i] for i in test_pred]
test_pred[:10]
# Out:
# ['e', 'e', 'e', 'p', 'e', 'e', 'e', 'e', 'e', 'e']

# %%
test_df['class'] = test_pred
test_df.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          5            3          9        1     0                1
# 1          0            2          9        1     0                1
# 2          0            3          8        1     0                1
# 3          2            2          8        1     6                1
# 4          2            0          4        0     5                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...    \
# 0             0          0           5            0  ...
# 1             0          0           4            0  ...
# 2             0          0          10            0  ...
# 3             0          1           5            0  ...
# 4             0          1           4            0  ...
#
#    stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 0                       7          0           2            1          4
# 1                       7          0           2            1          4
# 2                       7          0           2            1          4
# 3                       7          0           2            1          4
# 4                       7          0           2            1          4
#
#    spore-print-color  population  habitat  Id  class
# 0                  2           3        3  11      e
# 1                  3           3        3  20      e
# 2                  3           2        3  23      e
# 3                  3           4        1  25      p
# 4                  2           5        5  28      e
#
# [5 rows x 24 columns]

# %%
submission_df = test_df[['Id', 'class']]
submission_df.to_csv('submission.csv', index=False)
